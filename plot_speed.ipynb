# %%
import pandas as pd
csv_file = pd.read_csv('./wave.csv')
csv_df = pd.DataFrame(csv_file)

# %%
csv_df
# Out:
#       real12  inc12     pred12  real3  inc3      pred3
# 0       66.0    0.0  65.950386   70.0   0.0  66.531370
# 1       59.0    0.0  65.838850   66.0   0.0  66.867910
# 2       61.0    0.0  65.465126   66.0   0.0  67.045810
# 3       64.0    0.0  65.704380   67.0   0.0  67.764130
# 4       65.0    0.0  65.629420   66.0   0.0  67.654530
# ...      ...    ...        ...    ...   ...        ...
# 9662    65.0    0.0  65.832770   66.0   0.0  64.925780
# 9663    67.0    0.0  66.153885   60.0   0.0  65.469154
# 9664    66.0    0.0  66.044070   67.0   0.0  65.401010
# 9665    73.0    0.0  66.409350   64.0   0.0  65.882830
# 9666    66.0    0.0  66.502930   65.0   0.0  65.128204
#
# [9667 rows x 6 columns]

# %%
df_12_inc = csv_df[csv_df['inc12'] == 1]

# %%
# Incident under the 60 min
df_12_inc['real12'].plot(label='Ground Truth')
ax = df_12_inc['pred12'].plot(label='Prediction')
ax.legend()

# %%
# Non-incident under the 60 min
df_12_non = csv_df[csv_df['inc12'] == 0]
df_12_non['real12'].plot(label='Ground Truth')
ax = df_12_non['pred12'].plot(label='Prediction')
ax.legend()

# %%
# Incident under the 15 min
df_3_inc = csv_df[csv_df['inc3'] == 1]
df_3_inc['real3'].plot(label='Ground Truth')
ax = df_3_inc['pred3'].plot(label='Prediction')
ax.legend()

# %%
# Non-incident under the 15 min
df_3_non = csv_df[csv_df['inc3'] == 0]
df_3_non['real3'].plot(label='Ground Truth')
ax = df_3_non['pred3'].plot(label='Prediction')
ax.legend()
